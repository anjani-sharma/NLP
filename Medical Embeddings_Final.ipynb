# %% [markdown]
# # Medical Embeddings and clinical trial search engine

# %%
#  Importing Libraries

# %%
! pip install streamlit
# Out:
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/20/fb/c52ddcedbb0cb142ab6f22b6d1ccee6162ade7d61ca139bc064168262ced/streamlit-1.25.0-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.25.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/b2/20/5c3b89d6f8d9938325a9330793438389e0dc94c34d921f6da35ec62095f3/altair-5.0.1-py3-none-any.whl.metadata
#   Downloading altair-5.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Obtaining dependency information for click<9,>=7.0 from https://files.pythonhosted.org/packages/1a/70/e63223f8116931d365993d4a6b7ef653a4d920b41d03de7c59499962821f/click-8.1.6-py3-none-any.whl.metadata
#   Downloading click-8.1.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting importlib-metadata<7,>=1.4 (from streamlit)
#   Obtaining dependency information for importlib-metadata<7,>=1.4 from https://files.pythonhosted.org/packages/cc/37/db7ba97e676af155f5fcb1a35466f446eadc9104e25b83366e8088c9c926/importlib_metadata-6.8.0-py3-none-any.whl.metadata
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy<2,>=1.19.3 (from streamlit)
#   Obtaining dependency information for numpy<2,>=1.19.3 from https://files.pythonhosted.org/packages/72/b2/02770e60c4e2f7e158d923ab0dea4e9f146a2dbf267fec6d8dc61d475689/numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (23.1)
# Collecting pandas<3,>=1.3.0 (from streamlit)
#   Obtaining dependency information for pandas<3,>=1.3.0 from https://files.pythonhosted.org/packages/9e/71/756a1be6bee0209d8c0d8c5e3b9fc72c00373f384a4017095ec404aec3ad/pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Collecting pillow<10,>=7.1.0 (from streamlit)
#   Downloading Pillow-9.5.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      -------- ------------------------------- 0.6/2.5 MB 11.5 MB/s eta 0:00:01
#      ------------------ --------------------- 1.1/2.5 MB 12.0 MB/s eta 0:00:01
#      -------------------------- ------------- 1.7/2.5 MB 11.8 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.3/2.5 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 11.4 MB/s eta 0:00:00
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Obtaining dependency information for protobuf<5,>=3.20 from https://files.pythonhosted.org/packages/1c/1f/e64ec8bc540266178d4d0e0255e0c1427ba284ba951e193d193a238b09bb/protobuf-4.24.0-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.24.0-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Collecting pyarrow>=6.0 (from streamlit)
#   Obtaining dependency information for pyarrow>=6.0 from https://files.pythonhosted.org/packages/53/98/823deb5d3ff75386d5ab19b90c25b4a3aca01299bb53f217f2cfa954329c/pyarrow-12.0.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyarrow-12.0.1-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pympler<2,>=0.9 (from streamlit)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ---------------------------------------- 0.0/164.8 kB ? eta -:--:--
#      ------------------------------------- 164.8/164.8 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/8d/5f/21a93b2ec205f4b79853ff6e838e3c99064d5dbe85ec6b05967506f14af0/rich-13.5.2-py3-none-any.whl.metadata
#   Downloading rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit)
#   Obtaining dependency information for tenacity<9,>=8.1.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting typing-extensions<5,>=4.1.0 (from streamlit)
#   Obtaining dependency information for typing-extensions<5,>=4.1.0 from https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.7.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting tzlocal<5,>=1.1 (from streamlit)
#   Obtaining dependency information for tzlocal<5,>=1.1 from https://files.pythonhosted.org/packages/55/a6/a75af44665e5e77e52f6789eef4f8bc056c8e039d96c804b975806942580/tzlocal-4.3.1-py3-none-any.whl.metadata
#   Downloading tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/8d/e7/c2d0758c58dbd463b4a0a650f8cf3af5c4cbb6fbc61a36ce077964286feb/validators-0.21.2-py3-none-any.whl.metadata
#   Downloading validators-0.21.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/67/50/742c2fb60989b76ccf7302c7b1d9e26505d7054c24f08cc7ec187faaaea7/GitPython-3.1.32-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.32-py3-none-any.whl.metadata (10.0 kB)
# Collecting pydeck<1,>=0.8 (from streamlit)
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#      ---- ----------------------------------- 0.5/4.7 MB 16.8 MB/s eta 0:00:01
#      --------- ------------------------------ 1.2/4.7 MB 12.3 MB/s eta 0:00:01
#      -------------- ------------------------- 1.7/4.7 MB 13.4 MB/s eta 0:00:01
#      ------------------ --------------------- 2.2/4.7 MB 12.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.8/4.7 MB 12.7 MB/s eta 0:00:01
#      ---------------------------- ----------- 3.3/4.7 MB 12.6 MB/s eta 0:00:01
#      --------------------------------- ------ 3.9/4.7 MB 12.4 MB/s eta 0:00:01
#      ------------------------------------- -- 4.4/4.7 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------------- 4.7/4.7 MB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from streamlit) (6.3.2)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
#      ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#      ---------------------------------------- 82.0/82.0 kB ? eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.0)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#      ---------------------------------------- 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Collecting zipp>=0.5 (from importlib-metadata<7,>=1.4->streamlit)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/8c/08/d3006317aefe25ea79d3b76c9650afabaf6d63d1c8443b236e7405447503/zipp-3.16.2-py3-none-any.whl.metadata
#   Downloading zipp-3.16.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting pytz>=2020.1 (from pandas<3,>=1.3.0->streamlit)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas<3,>=1.3.0->streamlit)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: six>=1.5 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.18->streamlit) (2023.7.22)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.9.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading streamlit-1.25.0-py2.py3-none-any.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/8.1 MB 12.9 MB/s eta 0:00:01
#    --- ------------------------------------ 0.8/8.1 MB 9.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/8.1 MB 8.4 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.1 MB 9.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.1 MB 9.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.1 MB 8.7 MB/s eta 0:00:01
#    ------------ --------------------------- 2.6/8.1 MB 8.7 MB/s eta 0:00:01
#    -------------- ------------------------- 2.8/8.1 MB 8.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/8.1 MB 8.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.6/8.1 MB 8.3 MB/s eta 0:00:01
#    ------------------- -------------------- 4.0/8.1 MB 8.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.3/8.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.1 MB 7.9 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.1 MB 7.8 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 7.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 7.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 7.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.1 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.5/8.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.2 MB/s eta 0:00:00
# Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#    ---------------------------------------- 0.0/471.5 kB ? eta -:--:--
#    -------------------------------------- - 450.6/471.5 kB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 471.5/471.5 kB 9.8 MB/s eta 0:00:00
# Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Using cached click-8.1.6-py3-none-any.whl (97 kB)
# Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#    ---------------------------------------- 0.0/188.5 kB ? eta -:--:--
#    --------------------------------------- 188.5/188.5 kB 11.9 MB/s eta 0:00:00
# Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Using cached numpy-1.25.2-cp311-cp311-win_amd64.whl (15.5 MB)
# Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
# Downloading protobuf-4.24.0-cp310-abi3-win_amd64.whl (430 kB)
#    ---------------------------------------- 0.0/430.5 kB ? eta -:--:--
#    --------------------------------------  430.1/430.5 kB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 430.5/430.5 kB 9.1 MB/s eta 0:00:00
# Downloading pyarrow-12.0.1-cp311-cp311-win_amd64.whl (21.5 MB)
#    ---------------------------------------- 0.0/21.5 MB ? eta -:--:--
#     --------------------------------------- 0.4/21.5 MB 12.2 MB/s eta 0:00:02
#    - -------------------------------------- 0.9/21.5 MB 11.8 MB/s eta 0:00:02
#    -- ------------------------------------- 1.4/21.5 MB 11.5 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/21.5 MB 11.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.5/21.5 MB 11.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.1/21.5 MB 11.5 MB/s eta 0:00:02
#    ------ --------------------------------- 3.6/21.5 MB 11.5 MB/s eta 0:00:02
#    ------- -------------------------------- 4.1/21.5 MB 11.3 MB/s eta 0:00:02
#    -------- ------------------------------- 4.7/21.5 MB 11.4 MB/s eta 0:00:02
#    --------- ------------------------------ 5.2/21.5 MB 11.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.8/21.5 MB 11.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 6.3/21.5 MB 11.5 MB/s eta 0:00:02
#    ------------ --------------------------- 6.8/21.5 MB 11.5 MB/s eta 0:00:02
#    ------------- -------------------------- 7.4/21.5 MB 11.7 MB/s eta 0:00:02
#    -------------- ------------------------- 7.9/21.5 MB 11.7 MB/s eta 0:00:02
#    --------------- ------------------------ 8.4/21.5 MB 11.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 9.0/21.5 MB 11.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 9.5/21.5 MB 11.7 MB/s eta 0:00:02
#    ------------------ --------------------- 10.0/21.5 MB 11.6 MB/s eta 0:00:01
#    ------------------- -------------------- 10.6/21.5 MB 11.7 MB/s eta 0:00:01
#    -------------------- ------------------- 11.1/21.5 MB 11.7 MB/s eta 0:00:01
#    --------------------- ------------------ 11.7/21.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 12.2/21.5 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 12.7/21.5 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 13.3/21.5 MB 11.7 MB/s eta 0:00:01
#    ------------------------- -------------- 13.8/21.5 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 14.3/21.5 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 14.8/21.5 MB 11.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 15.2/21.5 MB 11.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 15.7/21.5 MB 11.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 15.9/21.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------ --------- 16.6/21.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 17.1/21.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 17.7/21.5 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 18.2/21.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 18.8/21.5 MB 11.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 19.3/21.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 19.8/21.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 20.4/21.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 20.9/21.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  21.4/21.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 21.5/21.5 MB 10.7 MB/s eta 0:00:00
# Downloading rich-13.5.2-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/239.7 kB ? eta -:--:--
#    --------------------------------------- 239.7/239.7 kB 15.3 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Downloading validators-0.21.2-py3-none-any.whl (25 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Downloading zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Installing collected packages: pytz, zipp, watchdog, validators, tzdata, typing-extensions, toolz, toml, tenacity, smmap, pympler, protobuf, pillow, numpy, mdurl, click, cachetools, blinker, pytz-deprecation-shim, pydeck, pyarrow, pandas, markdown-it-py, importlib-metadata, gitdb, tzlocal, rich, gitpython, altair, streamlit
# Successfully installed altair-5.0.1 blinker-1.6.2 cachetools-5.3.1 click-8.1.6 gitdb-4.0.10 gitpython-3.1.32 importlib-metadata-6.8.0 markdown-it-py-3.0.0 mdurl-0.1.2 numpy-1.25.2 pandas-2.0.3 pillow-9.5.0 protobuf-4.24.0 pyarrow-12.0.1 pydeck-0.8.0 pympler-1.0.1 pytz-2023.3 pytz-deprecation-shim-0.1.0.post0 rich-13.5.2 smmap-5.0.0 streamlit-1.25.0 tenacity-8.2.3 toml-0.10.2 toolz-0.12.0 typing-extensions-4.7.1 tzdata-2023.3 tzlocal-4.3.1 validators-0.21.2 watchdog-3.0.0 zipp-3.16.2

# %%
import streamlit as st  #importing streamlit liabrary

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (0.0.post7)

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/77/85/bff3a1e818ec6aa3dd466ff4f4b0a727db9fdb41f2e849747ad902ddbe95/scikit_learn-1.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.3.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.3.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Using cached scikit_learn-1.3.0-cp311-cp311-win_amd64.whl (9.2 MB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.3.0 threadpoolctl-3.2.0

# %%
# !pip install pandas
# !pip install numpy
# !pip install gensim
# !pip install matplotlib
# !pip install sklearn
# !pip install nltk
# Out:
# Requirement already satisfied: pandas in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (1.25.2)
# Requirement already satisfied: gensim in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from gensim) (6.3.0)
# Requirement already satisfied: matplotlib in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (0.0.post7)
# Requirement already satisfied: nltk in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)

# %%
pip install plotly
# Out:
# Collecting plotly
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/d6/54/a8759957b778094233d7058c8ddbe368504b448ffe9c26a85f7bfd53584e/plotly-5.16.0-py2.py3-none-any.whl.metadata
#   Downloading plotly-5.16.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from plotly) (23.1)
# Downloading plotly-5.16.0-py2.py3-none-any.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.6 MB 9.6 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/15.6 MB 10.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/15.6 MB 11.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/15.6 MB 11.3 MB/s eta 0:00:02
#    ------ --------------------------------- 2.7/15.6 MB 11.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/15.6 MB 11.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.8/15.6 MB 11.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.4/15.6 MB 11.6 MB/s eta 0:00:01
#    ------------ --------------------------- 4.9/15.6 MB 11.6 MB/s eta 0:00:01
#    -------------- ------------------------- 5.5/15.6 MB 11.6 MB/s eta 0:00:01
#    --------------- ------------------------ 6.0/15.6 MB 11.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.5/15.6 MB 11.9 MB/s eta 0:00:01
#    ------------------ --------------------- 7.1/15.6 MB 11.9 MB/s eta 0:00:01
#    ------------------- -------------------- 7.6/15.6 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.7/15.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.3/15.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------- -------------- 9.9/15.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------- ------------- 10.4/15.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.6 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.6 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.6 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: plotly
# Successfully installed plotly-5.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import gensim

from gensim.models import Word2Vec
from gensim.models import FastText
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
import matplotlib.pyplot as plt # our main display package
import plotly.graph_objects as go
import string # used for preprocessing
import re # used for preprocessing
import nltk # the Natural Language Toolkit, used for preprocessing
import numpy as np # used for managing NaNs
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from sklearn.model_selection import train_test_split
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anjan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anjan\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anjan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# # Importing datasets

# %%
df=pd.read_csv('Dimension-covid.csv')   #for preprocessing
df1=pd.read_csv('Dimension-covid.csv')  #for returning results

# %% [markdown]
# # Preprocessing data

# %%
# understand the data

df.shape
# Out:
# (10666, 21)

# %%
# understand the data

df.head()
# Out:
#    Date added     Trial ID                                              Title  \
# 0  2021-06-04  NCT04912934  The Relationship Between Coronavirus Anxiety L...
# 1  2021-06-04  NCT04912921  Effect of Palmitoylethanolamide on Proinflamma...
# 2  2021-06-04  NCT04912895  Detection of SARS-CoV-2 RNA and Biomarkers in ...
# 3  2021-06-04  NCT04912817  Pain Rehabilitation Virtual Reality (PR-VR) At...
# 4  2021-06-04  NCT04912804  Perceived Health After Hospitalization for COV...
#
#                                          Brief title    Acronym  \
# 0  The Relationship Between COVID-19 Anxiety Leve...   COVID-19
# 1  Effect of Palmitoylethanolamide on Proinflamma...        NaN
# 2  Detection of SARS-CoV-2 RNA in Coughed Droplet...        NaN
# 3    PR-VR At-home Program During and After COVID-19        NaN
# 4  Perceived Health After Hospitalization for COV...  PRO-COVID
#
#                                             Abstract Publication date  \
# 0  The aim was to determine the coronavirus anxie...       2020-06-20
# 1  This is a randomized controlled trial to exami...       2020-10-20
# 2  The purpose of this study is to learn how to b...       2021-04-14
# 3  Poorly controlled chronic pain in teens can im...       2021-09-01
# 4  There are currently no precise data available ...       2020-06-30
#
#        Active years Phase                                      Conditions  \
# 0              2020   NaN  COVID-19; Emotional Eating; Metabolic Syndrome
# 1  2020; 2021; 2022   NaN                           COVID19; Inflammation
# 2        2021; 2022   NaN                                         Covid19
# 3        2021; 2022   NaN                                   Pain, Chronic
# 4        2020; 2021   NaN  COVID-19, Post-hospitalization, Disease Impact
#
#    ... Gender            Registry Investigators/Contacts  \
# 0  ...    All  ClinicalTrials.gov    Dilek Küçük Alemdar
# 1  ...    All  ClinicalTrials.gov                    NaN
# 2  ...    All  ClinicalTrials.gov         Larry Anderson
# 3  ...    All  ClinicalTrials.gov       Jennifer Stinson
# 4  ...    All  ClinicalTrials.gov                    NaN
#
#                               Sponsors/Collaborators  \
# 0                                    Ordu University
# 1                           Arizona State University
# 2  Emory University Hospital Midtown; Emory Unive...
# 3    Hospital for Sick Children; Stanford University
# 4   Centre Hospitalier Universitaire Dijon Bourgogne
#
#                                             GRID IDs  \
# 0                                      grid.412366.4
# 1                                      grid.215654.1
# 2  grid.411929.6; grid.412162.2; grid.189967.8; g...
# 3                       grid.42327.30; grid.168010.e
# 4                                      grid.31151.37
#
#                      Country of Sponsor/Collaborator  \
# 0                                             Turkey
# 1                                      United States
# 2  United States; United States; United States; U...
# 3                              Canada; United States
# 4                                             France
#
#         Collaborating Funders Funder Country  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3  Hospital for Sick Children         Canada
# 4                         NaN            NaN
#
#                                 Source Linkout  \
# 0  https://clinicaltrials.gov/show/NCT04912934
# 1  https://clinicaltrials.gov/show/NCT04912921
# 2  https://clinicaltrials.gov/show/NCT04912895
# 3  https://clinicaltrials.gov/show/NCT04912817
# 4  https://clinicaltrials.gov/show/NCT04912804
#
#                                       Dimensions URL
# 0  https://app.dimensions.ai/details/clinical_tri...
# 1  https://app.dimensions.ai/details/clinical_tri...
# 2  https://app.dimensions.ai/details/clinical_tri...
# 3  https://app.dimensions.ai/details/clinical_tri...
# 4  https://app.dimensions.ai/details/clinical_tri...
#
# [5 rows x 21 columns]

# %%
df['Abstract'][0]
# Out:
# 'The aim was to determine the coronavirus anxiety levels and emotional eating status of cases with diagnosis of MetS according to diagnostic criteria published by the International Diabetic Federation (IDF) in 2005 and healthy individuals with similar BMI to MetS subjects.\n\nDetailed Description\nThe aim was to determine the coronavirus anxiety levels and emotional eating status of cases with diagnosis of MetS according to diagnostic criteria published by the International Diabetic Federation (IDF) in 2005 and healthy individuals with similar BMI to MetS subjects. This study was completed with the descriptive, cross-sectional and relational screening model. The full sampling method was used in the study. The study was completed with 105 individuals with metabolic syndrome attending the diet clinic and 109 healthy individuals without MetS diagnosis also attending the diet clinic. Collection of data used anthropometric measurements and biochemical findings, blood pressure and a survey form, the Coronavirus Anxiety Scale (CAS) and Emotional Eating Scale (EES).'

# %%
# function to remove all urls
def remove_urls(text):    
    new_text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())
    return new_text

# make all text lowercase
def text_lowercase(text):
    return text.lower()

# remove numbers
def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result

# remove punctuation
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# tokenize
def tokenize(text):
    text = word_tokenize(text)
    return text

# remove stopwords
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    text = [i for i in text if not i in stop_words]
    return text

# lemmatize Words 
lemmatizer = WordNetLemmatizer()
def lemmatize(text):
    text = [lemmatizer.lemmatize(token) for token in text]
    return text

#Creating one function so that all functions can be applied at once
def preprocessing(text):
    
    text = text_lowercase(text)
    text = remove_urls(text)
    text = remove_numbers(text)
    text = remove_punctuation(text)
    text = tokenize(text)
    text = remove_stopwords(text)
    text = lemmatize(text)
    text = ' '.join(text)
    return text

# %%
#Applying preprocessing and removing '\n' character

for i in range(df.shape[0]):
    df['Abstract'][i]=preprocessing(str(df['Abstract'][i])) 
for text in df.Abstract:

    text=text.replace('\n',' ')

# %%
df.head()
# Out:
#    Date added     Trial ID                                              Title  \
# 0  2021-06-04  NCT04912934  The Relationship Between Coronavirus Anxiety L...
# 1  2021-06-04  NCT04912921  Effect of Palmitoylethanolamide on Proinflamma...
# 2  2021-06-04  NCT04912895  Detection of SARS-CoV-2 RNA and Biomarkers in ...
# 3  2021-06-04  NCT04912817  Pain Rehabilitation Virtual Reality (PR-VR) At...
# 4  2021-06-04  NCT04912804  Perceived Health After Hospitalization for COV...
#
#                                          Brief title    Acronym  \
# 0  The Relationship Between COVID-19 Anxiety Leve...   COVID-19
# 1  Effect of Palmitoylethanolamide on Proinflamma...        NaN
# 2  Detection of SARS-CoV-2 RNA in Coughed Droplet...        NaN
# 3    PR-VR At-home Program During and After COVID-19        NaN
# 4  Perceived Health After Hospitalization for COV...  PRO-COVID
#
#                                             Abstract Publication date  \
# 0  aim determine coronavirus anxiety level emotio...       2020-06-20
# 1  randomized controlled trial examine effect foo...       2020-10-20
# 2  purpose study learn better detect infection un...       2021-04-14
# 3  poorly controlled chronic pain teen impact qua...       2021-09-01
# 4  currently precise data available impact covid ...       2020-06-30
#
#        Active years Phase                                      Conditions  \
# 0              2020   NaN  COVID-19; Emotional Eating; Metabolic Syndrome
# 1  2020; 2021; 2022   NaN                           COVID19; Inflammation
# 2        2021; 2022   NaN                                         Covid19
# 3        2021; 2022   NaN                                   Pain, Chronic
# 4        2020; 2021   NaN  COVID-19, Post-hospitalization, Disease Impact
#
#    ... Gender            Registry Investigators/Contacts  \
# 0  ...    All  ClinicalTrials.gov    Dilek Küçük Alemdar
# 1  ...    All  ClinicalTrials.gov                    NaN
# 2  ...    All  ClinicalTrials.gov         Larry Anderson
# 3  ...    All  ClinicalTrials.gov       Jennifer Stinson
# 4  ...    All  ClinicalTrials.gov                    NaN
#
#                               Sponsors/Collaborators  \
# 0                                    Ordu University
# 1                           Arizona State University
# 2  Emory University Hospital Midtown; Emory Unive...
# 3    Hospital for Sick Children; Stanford University
# 4   Centre Hospitalier Universitaire Dijon Bourgogne
#
#                                             GRID IDs  \
# 0                                      grid.412366.4
# 1                                      grid.215654.1
# 2  grid.411929.6; grid.412162.2; grid.189967.8; g...
# 3                       grid.42327.30; grid.168010.e
# 4                                      grid.31151.37
#
#                      Country of Sponsor/Collaborator  \
# 0                                             Turkey
# 1                                      United States
# 2  United States; United States; United States; U...
# 3                              Canada; United States
# 4                                             France
#
#         Collaborating Funders Funder Country  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3  Hospital for Sick Children         Canada
# 4                         NaN            NaN
#
#                                 Source Linkout  \
# 0  https://clinicaltrials.gov/show/NCT04912934
# 1  https://clinicaltrials.gov/show/NCT04912921
# 2  https://clinicaltrials.gov/show/NCT04912895
# 3  https://clinicaltrials.gov/show/NCT04912817
# 4  https://clinicaltrials.gov/show/NCT04912804
#
#                                       Dimensions URL
# 0  https://app.dimensions.ai/details/clinical_tri...
# 1  https://app.dimensions.ai/details/clinical_tri...
# 2  https://app.dimensions.ai/details/clinical_tri...
# 3  https://app.dimensions.ai/details/clinical_tri...
# 4  https://app.dimensions.ai/details/clinical_tri...
#
# [5 rows x 21 columns]

# %%
df['Abstract'][0]
# Out:
# 'aim determine coronavirus anxiety level emotional eating status case diagnosis mets according diagnostic criterion published international diabetic federation idf healthy individual similar bmi mets subject detailed description aim determine coronavirus anxiety level emotional eating status case diagnosis mets according diagnostic criterion published international diabetic federation idf healthy individual similar bmi mets subject study completed descriptive cross sectional relational screening model full sampling method used study study completed individual metabolic syndrome attending diet clinic healthy individual without mets diagnosis also attending diet clinic collection data used anthropometric measurement biochemical finding blood pressure survey form coronavirus anxiety scale ca emotional eating scale ee'

# %%
#Applying preprocessing and removing '\n' character

for i in range(df.shape[0]):
    df['Title'][i]=preprocessing(str(df['Title'][i])) 
for text in df.Title:

    text=text.replace('\n',' ')

# %%
x=[word_tokenize(word) for word in df.Abstract ]   #Tokenizing data for training purpose

# %% [markdown]
# # Exploratory data analysis

# %%
from collections import Counter
cnt = Counter()
for text in df["Abstract"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)  #top 10 common words
# Out:
# [('patient', 38457),
#  ('covid', 38211),
#  ('study', 31963),
#  ('group', 12771),
#  ('treatment', 12471),
#  ('day', 12337),
#  ('sars', 11600),
#  ('cov', 11535),
#  ('clinical', 11507),
#  ('disease', 11395)]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/34/ac/72a4e42e76bf549dfd91791a6b10a9832f046c1d48b5e778be9ec012aa47/wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anjan\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    ---------------------------------------- 151.4/151.4 kB ? eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
#Final word cloud after all the cleaning and pre-processing
from wordcloud import WordCloud
from textwrap import wrap
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
#comment_words = ' '
stopwords = set(STOPWORDS) 
from pandas.core.common import flatten

# iterate through the csv file 


comment_words=flatten(x)
comment_words=' '.join(comment_words)


wordcloud = WordCloud(width = 800, height = 800, 
            background_color ='white', 
            stopwords = stopwords, 
            min_font_size = 10).generate(comment_words) 

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %% [markdown]
# # Training skipgram model

# %%
# training the model

skipgram = Word2Vec(x, vector_size =50, window = 3, min_count=2,sg = 1)
print(skipgram)
skipgram.save('skipgramx1.bin')
# Out:
# Word2Vec<vocab=24877, vector_size=50, alpha=0.025>

# %%
# training the model

skipgram = Word2Vec(x, vector_size =100, window = 1, min_count=2,sg = 1)
print(skipgram)
skipgram.save('skipgramx11.bin')
# Out:
# Word2Vec<vocab=24877, vector_size=100, alpha=0.025>

# %%
# Loading the model
skipgram = Word2Vec.load('skipgramx11.bin')

# %% [markdown]
# # Training Fasttext model

# %%
#fast_n= FastText(x,vector_size=200, window=3, min_count=2, workers=5, min_n=1, max_n=2,sg=1)  #training fasttext Model, with skipgram
#fast_n=fast_n.save('fast_p.bin')    #Saving our model
fast_n = Word2Vec.load('fast_p.bin')  #Loading our pretrained model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 3
#       1 #fast_n= FastText(x,vector_size=200, window=3, min_count=2, workers=5, min_n=1, max_n=2,sg=1)  #training fasttext Model, with skipgram
#       2 #fast_n=fast_n.save('fast_p.bin')    #Saving our model
# ----> 3 fast_n = Word2Vec.load('fast_p.bin')  #Loading our pretrained model
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\models\word2vec.py:1953, in Word2Vec.load(cls, rethrow, *args, **kwargs)
#    1934 """Load a previously saved :class:`~gensim.models.word2vec.Word2Vec` model.
#    1935
#    1936 See Also
#    (...)
#    1950
#    1951 """
#    1952 try:
# -> 1953     model = super(Word2Vec, cls).load(*args, **kwargs)
#    1954     if not isinstance(model, Word2Vec):
#    1955         rethrow = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\utils.py:486, in SaveLoad.load(cls, fname, mmap)
#     482 logger.info("loading %s object from %s", cls.__name__, fname)
#     484 compress, subname = SaveLoad._adapt_by_suffix(fname)
# --> 486 obj = unpickle(fname)
#     487 obj._load_specials(fname, mmap, compress, subname)
#     488 obj.add_lifecycle_event("loaded", fname=fname)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\utils.py:1460, in unpickle(fname)
#    1446 def unpickle(fname):
#    1447     """Load object from `fname`, using smart_open so that `fname` can be on S3, HDFS, compressed etc.
#    1448
#    1449     Parameters
#    (...)
#    1458
#    1459     """
# -> 1460     with open(fname, 'rb') as f:
#    1461         return _pickle.load(f, encoding='latin1')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\smart_open\smart_open_lib.py:177, in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, compression, transport_params)
#     174 if transport_params is None:
#     175     transport_params = {}
# --> 177 fobj = _shortcut_open(
#     178     uri,
#     179     mode,
#     180     compression=compression,
#     181     buffering=buffering,
#     182     encoding=encoding,
#     183     errors=errors,
#     184     newline=newline,
#     185 )
#     186 if fobj is not None:
#     187     return fobj
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\smart_open\smart_open_lib.py:363, in _shortcut_open(uri, mode, compression, buffering, encoding, errors, newline)
#     360 if errors and 'b' not in mode:
#     361     open_kwargs['errors'] = errors
# --> 363 return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fast_p.bin'

# %%
FastText=FastText(x,vector_size=100, window=2, min_count=2, workers=5, min_n=1, max_n=2,sg=1)
FastText.save('FastText.bin')    #Saving our model
FastText = Word2Vec.load('FastText.bin')  #Loading our pretrained model
# Out:
# 2021-07-23 12:38:07.194 INFO    gensim.models.word2vec: collecting all words and their counts
# 2021-07-23 12:38:07.195 INFO    gensim.models.word2vec: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-07-23 12:38:07.551 INFO    gensim.models.word2vec: PROGRESS: at sentence #10000, processed 2024809 words, keeping 39392 word types
# 2021-07-23 12:38:07.563 INFO    gensim.models.word2vec: collected 39969 word types from a corpus of 2088009 raw words and 10666 sentences
# 2021-07-23 12:38:07.563 INFO    gensim.models.word2vec: Creating a fresh vocabulary
# 2021-07-23 12:38:07.643 INFO    gensim.utils: FastText lifecycle event {'msg': 'effective_min_count=2 retains 24877 unique words (62.2407365708424%% of original 39969, drops 15092)', 'datetime': '2021-07-23T12:38:07.643433', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-07-23 12:38:07.643 INFO    gensim.utils: FastText lifecycle event {'msg': 'effective_min_count=2 leaves 2072917 word corpus (99.2772061806247%% of original 2088009, drops 15092)', 'datetime': '2021-07-23T12:38:07.643433', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-07-23 12:38:07.763 INFO    gensim.models.word2vec: deleting the raw counts dictionary of 39969 items
# 2021-07-23 12:38:07.763 INFO    gensim.models.word2vec: sample=0.001 downsamples 32 most-common words
# 2021-07-23 12:38:07.763 INFO    gensim.utils: FastText lifecycle event {'msg': 'downsampling leaves estimated 1928478.8939992087 word corpus (93.0%% of prior 2072917)', 'datetime': '2021-07-23T12:38:07.763881', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-07-23 12:38:08.074 INFO    gensim.models.fasttext: estimated required memory for 24877 words, 2000000 buckets and 100 dimensions: 836440980 bytes
# 2021-07-23 12:38:08.074 INFO    gensim.models.word2vec: resetting layer weights
# 2021-07-23 12:38:09.925 INFO    gensim.utils: FastText lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-07-23T12:38:09.925456', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'build_vocab'}
# 2021-07-23 12:38:09.925 INFO    gensim.utils: FastText lifecycle event {'msg': 'training model with 5 workers on 24877 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=2', 'datetime': '2021-07-23T12:38:09.925456', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2021-07-23 12:38:10.933 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 16.45% examples, 355385 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:11.945 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 32.23% examples, 337669 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:12.952 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 51.32% examples, 353282 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:13.985 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 71.13% examples, 362965 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:14.995 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 95.61% examples, 370672 words/s, in_qsize 6, out_qsize 0
# 2021-07-23 12:38:15.015 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 4 more threads
# 2021-07-23 12:38:15.023 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 3 more threads
# 2021-07-23 12:38:15.053 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 2 more threads
# 2021-07-23 12:38:15.069 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 1 more threads
# 2021-07-23 12:38:15.093 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 0 more threads
# 2021-07-23 12:38:15.094 INFO    gensim.models.word2vec: EPOCH - 1 : training on 2088009 raw words (1928472 effective words) took 5.2s, 373492 effective words/s
# 2021-07-23 12:38:16.095 INFO    gensim.models.word2vec: EPOCH 2 - PROGRESS: at 17.51% examples, 374290 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:17.107 INFO    gensim.models.word2vec: EPOCH 2 - PROGRESS: at 38.53% examples, 405609 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:18.115 INFO    gensim.models.word2vec: EPOCH 2 - PROGRESS: at 59.98% examples, 410602 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:19.152 INFO    gensim.models.word2vec: EPOCH 2 - PROGRESS: at 81.61% examples, 412609 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:19.675 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 4 more threads
# 2021-07-23 12:38:19.683 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 3 more threads
# 2021-07-23 12:38:19.700 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 2 more threads
# 2021-07-23 12:38:19.713 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 1 more threads
# 2021-07-23 12:38:19.720 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 0 more threads
# 2021-07-23 12:38:19.720 INFO    gensim.models.word2vec: EPOCH - 2 : training on 2088009 raw words (1928860 effective words) took 4.6s, 417188 effective words/s
# 2021-07-23 12:38:20.742 INFO    gensim.models.word2vec: EPOCH 3 - PROGRESS: at 17.51% examples, 368469 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:21.763 INFO    gensim.models.word2vec: EPOCH 3 - PROGRESS: at 37.05% examples, 382965 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:22.768 INFO    gensim.models.word2vec: EPOCH 3 - PROGRESS: at 56.75% examples, 386331 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:23.768 INFO    gensim.models.word2vec: EPOCH 3 - PROGRESS: at 76.11% examples, 388856 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:24.580 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 4 more threads
# 2021-07-23 12:38:24.608 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 3 more threads
# 2021-07-23 12:38:24.628 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 2 more threads
# 2021-07-23 12:38:24.633 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 1 more threads
# 2021-07-23 12:38:24.643 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 0 more threads
# 2021-07-23 12:38:24.643 INFO    gensim.models.word2vec: EPOCH - 3 : training on 2088009 raw words (1928543 effective words) took 4.9s, 392093 effective words/s
# 2021-07-23 12:38:25.655 INFO    gensim.models.word2vec: EPOCH 4 - PROGRESS: at 17.51% examples, 370441 words/s, in_qsize 10, out_qsize 0
# 2021-07-23 12:38:26.676 INFO    gensim.models.word2vec: EPOCH 4 - PROGRESS: at 35.31% examples, 367221 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:27.698 INFO    gensim.models.word2vec: EPOCH 4 - PROGRESS: at 53.46% examples, 364478 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:28.706 INFO    gensim.models.word2vec: EPOCH 4 - PROGRESS: at 71.40% examples, 363426 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:29.705 INFO    gensim.models.word2vec: EPOCH 4 - PROGRESS: at 90.47% examples, 360639 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:29.915 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 4 more threads
# 2021-07-23 12:38:29.915 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 3 more threads
# 2021-07-23 12:38:29.956 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 2 more threads
# 2021-07-23 12:38:29.964 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 1 more threads
# 2021-07-23 12:38:29.974 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 0 more threads
# 2021-07-23 12:38:29.974 INFO    gensim.models.word2vec: EPOCH - 4 : training on 2088009 raw words (1928683 effective words) took 5.3s, 362016 effective words/s
# 2021-07-23 12:38:31.000 INFO    gensim.models.word2vec: EPOCH 5 - PROGRESS: at 16.08% examples, 338747 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:32.013 INFO    gensim.models.word2vec: EPOCH 5 - PROGRESS: at 35.39% examples, 365810 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:33.017 INFO    gensim.models.word2vec: EPOCH 5 - PROGRESS: at 53.96% examples, 368722 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:34.016 INFO    gensim.models.word2vec: EPOCH 5 - PROGRESS: at 71.69% examples, 366475 words/s, in_qsize 9, out_qsize 0
# 2021-07-23 12:38:35.024 INFO    gensim.models.word2vec: EPOCH 5 - PROGRESS: at 92.93% examples, 368600 words/s, in_qsize 8, out_qsize 0
# 2021-07-23 12:38:35.136 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 4 more threads
# 2021-07-23 12:38:35.146 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 3 more threads
# 2021-07-23 12:38:35.191 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 2 more threads
# 2021-07-23 12:38:35.203 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 1 more threads
# 2021-07-23 12:38:35.203 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 0 more threads
# 2021-07-23 12:38:35.203 INFO    gensim.models.word2vec: EPOCH - 5 : training on 2088009 raw words (1928303 effective words) took 5.2s, 368543 effective words/s
# 2021-07-23 12:38:35.203 INFO    gensim.utils: FastText lifecycle event {'msg': 'training on 10440045 raw words (9642861 effective words) took 25.3s, 381393 effective words/s', 'datetime': '2021-07-23T12:38:35.203660', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2021-07-23 12:38:36.070 INFO    gensim.utils: FastText lifecycle event {'params': 'FastText(vocab=24877, vector_size=100, alpha=0.025)', 'datetime': '2021-07-23T12:38:36.070935', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 2021-07-23 12:38:36.070 INFO    gensim.utils: FastText lifecycle event {'fname_or_handle': 'FastText.bin', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-07-23T12:38:36.070935', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'saving'}
# 2021-07-23 12:38:36.070 INFO    gensim.utils: storing np array 'vectors_ngrams' to FastText.bin.wv.vectors_ngrams.npy
# 2021-07-23 12:38:40.643 INFO    gensim.utils: not storing attribute buckets_word
# 2021-07-23 12:38:40.645 INFO    gensim.utils: not storing attribute vectors
# 2021-07-23 12:38:40.645 INFO    gensim.utils: not storing attribute cum_table
# 2021-07-23 12:38:40.662 INFO    gensim.utils: saved FastText.bin
# 2021-07-23 12:38:40.662 INFO    gensim.utils: loading Word2Vec object from FastText.bin
# 2021-07-23 12:38:40.683 INFO    gensim.utils: loading wv recursively from FastText.bin.wv.* with mmap=None
# 2021-07-23 12:38:40.683 INFO    gensim.utils: loading vectors_ngrams from FastText.bin.wv.vectors_ngrams.npy with mmap=None
# 2021-07-23 12:38:40.943 INFO    gensim.utils: setting ignored attribute buckets_word to None
# 2021-07-23 12:38:40.943 INFO    gensim.utils: setting ignored attribute vectors to None
# 2021-07-23 12:38:41.769 INFO    gensim.utils: setting ignored attribute cum_table to None
# 2021-07-23 12:38:41.945 INFO    gensim.utils: FastText lifecycle event {'fname': 'FastText.bin', 'datetime': '2021-07-23T12:38:41.945732', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'loaded'}

# %% [markdown]
# ## Model embeddings - Similarity

# %%
# Similar words - skipgram

skipgram.wv.most_similar(positive=['corona'],topn=10)
# Out:
# [('coronavirus', 0.7514869570732117),
#  ('covid', 0.7044876217842102),
#  ('novelty', 0.6873722672462463),
#  ('evd', 0.6854491233825684),
#  ('crown', 0.6740575432777405),
#  ('ebola', 0.668819785118103),
#  ('declares', 0.6625851988792419),
#  ('coronovirus', 0.6620121002197266),
#  ('virulent', 0.6609188914299011),
#  ('betacoronavirus', 0.6589146852493286)]

# %%
skipgram.wv.most_similar(positive=['patient'],topn=10)
# Out:
# [('hospitalised', 0.7466251850128174),
#  ('subject', 0.740435004234314),
#  ('participant', 0.7355508804321289),
#  ('acutely', 0.732078492641449),
#  ('individual', 0.7294858694076538),
#  ('moderately', 0.7208532691001892),
#  ('recovering', 0.7088289856910706),
#  ('survivor', 0.6963086724281311),
#  ('pwcf', 0.6935908794403076),
#  ('lymphocytopenia', 0.6920685172080994)]

# %%
# Similar words - fasttext

FastText.wv.most_similar(positive=['lung'],topn=10)
# Out:
# [('lungiq', 0.7391721606254578),
#  ('leung', 0.7318173050880432),
#  ('pulmonary', 0.6996168494224548),
#  ('laying', 0.6874018907546997),
#  ('lag', 0.6839495301246643),
#  ('laung', 0.679499626159668),
#  ('volunteering', 0.6774570345878601),
#  ('sung', 0.6764991879463196),
#  ('clungene', 0.6753350496292114),
#  ('lang', 0.673167884349823)]

# %%
FastText.wv.most_similar(positive=['breathing'],topn=10)
# Out:
# [('breaching', 0.9200581312179565),
#  ('rebreathing', 0.918149471282959),
#  ('breathe', 0.880999743938446),
#  ('breaking', 0.8744059205055237),
#  ('bathing', 0.8707643747329712),
#  ('breath', 0.8598464131355286),
#  ('breathed', 0.8542757630348206),
#  ('breathable', 0.8439397811889648),
#  ('babybreathe', 0.8394759893417358),
#  ('threatening', 0.8362838625907898)]

# %% [markdown]
# # PCA Plot - Skipgram

# %%
X = skipgram.wv[skipgram.wv.index_to_key]    #stroing arrays of all words
pca = PCA(n_components=2)                    #applying PCA to convert data into two dimensions
result = pca.fit_transform(X)

# %%
#words embeddings on the plot to check 2-D representation of each word
pyplot.scatter(result[:10, 0], result[:10, 1])
words = list(skipgram.wv.index_to_key)
for i, word in enumerate(words[:10]):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %% [markdown]
# # PCA Plot - Fasttest

# %%
#same thing as above but with fasttext model
X_fast = FastText.wv[FastText.wv.index_to_key]
pca = PCA(n_components=2)
result_fast = pca.fit_transform(X_fast)

# %%
pyplot.scatter(result_fast[:10, 0], result_fast[:10, 1])
words = list(FastText.wv.index_to_key)
for i, word in enumerate(words[:10]):
    pyplot.annotate(word, xy=(result_fast[i, 0], result_fast[i, 1]))
pyplot.show()

# %% [markdown]
# # Getting Vectors for each abstract

# %%
vector_size=100   #defining vector size for each word

# %% [markdown]
# ### Method 1

# %%
#function to take average of all vectors of each word in abstract, so that each abstract can represent (1,100) dimensional vector

K1=[]      #creating list to store vector representation of each abstract

for i in range(df.shape[0]):       #iterating through all abstract
    K=np.zeros([vector_size,1])    #creating empty array of size (vec_size,1) to add vector representation of each word
    count=0                        #creating count to check how many words are used from abstract
    
    for word in word_tokenize(df['Abstract'][i]):   #iterating through all words in given abstract

        if word in list(FastText.wv.index_to_key):      #if word exists in vocab , increase count by 1 and add array of given words in our defined array K

            count+=1
            K+=FastText.wv[word].reshape(vector_size,1)
    K=K/count                                        #taking average of given array
    K1.append(list(K))                               #appending vector of given abstract to the initial defined list
K1_array=np.array(K1)
K1_array=K1_array.reshape(df.shape[0],vector_size)   #converting into array of shape(no. of rows, vector_size)

# %%
# Method 1 will take time to run. Method 2 is prefered.

# %% [markdown]
# ### Method 2

# %%
def get_mean_vector(word2vec_model, words):
    # remove out-of-vocabulary words
    words = [word for word in tokenize(words) if word in list(word2vec_model.wv.index_to_key)] #if word is in vocab 
    if len(words) >= 1:
        return np.mean(word2vec_model.wv[words], axis=0)
    else:
        return np.array([0]*100)

# %% [markdown]
# ### Abstract to vectors using skipgram Model

# %%
K1=[]                                     #defining empty list
for i in df.Abstract:
    K1.append(list(get_mean_vector(skipgram, i)))     #appending array to the list
    
    
K11=pd.DataFrame(K1).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K11.to_csv('skipgram-vec.csv')

# %%
K=pd.read_csv('skipgram-vec.csv')   #Loading our pretrained vectors of each abstract

skipgram_vectors=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    skipgram_vectors.append(K[str(i)].values)

# %% [markdown]
# ### For converting Title into vectors using skipgram

# %%
K1_title=[]
for i in df.Title:         #instead of abstract use title
    K1_title.append(list(get_mean_vector(skipgram, i)))    

    
K1_title=pd.DataFrame(K1).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K1_title.to_csv('skipgram-vec-title.csv')

# %%
K=pd.read_csv('skipgram-vec-title.csv')   #Loading our pretrained vectors of each abstract

K2_title=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    K2_title.append(K[str(i)].values)

# %% [markdown]
# ### Abstract to vector using FastText

# %%
K_fast=[]                                     #defining empty list
for i in df.Abstract:
    K_fast.append(list(get_mean_vector(FastText, i)))     #appending array to the list
    
K11=pd.DataFrame(K_fast).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K11.to_csv('FastText-vec.csv')

# %%
data=pd.read_csv('FastText-vec.csv')   #Loading our pretrained vectors of each abstract

fast_vectors=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    fast_vectors.append(data[str(i)].values)

# %% [markdown]
# # Cosine similarity function

# %%
#defining function to define cosine similarity

from numpy import dot
from numpy.linalg import norm

def cos_sim(a,b):

    return dot(a, b)/(norm(a)*norm(b))

# %% [markdown]
# # Input query Preprocessing

# %%
#Preprocessing input, because input should be in same form as training data set


def preprocessing_input(query,word2vec_model):
    query=preprocessing(query)
    query=query.replace('\n',' ')
    K=get_mean_vector(word2vec_model,query)
   
        
    return K

# %% [markdown]
# # Function to return 'n' similar results

# %%
pd.set_option("display.max_colwidth", -1)       #this function will display full text from each column

# %%
#function to return top n similar results

#query - input query
# p - average vectors for all abs
#df1 - original

def top_n(query,p,df1,model):    
    print(query)
    
    query=preprocessing_input(query,model)    #preprocessing input to list of vectors
                                    
    x=[]
    #Converting cosine similarities of overall data set with input queries into LIST
    for i in range(len(p)):
        x.append(cos_sim(query,p[i]))
    
    
 #store list in tmp to retrieve index
    tmp=list(x)
    
 #sort list so that largest elements are on the far right
    
    res = sorted(range(len(x)), key = lambda sub: x[sub])[-5:]
    sim=[tmp[i] for i in reversed(res)]
    print(sim)
 #get index of the 10 or n largest element
    L=[]
    for i in reversed(res):
    
        L.append(i)
    return df1.iloc[L, [1,2,5,6]],sim     #returning dataframe (only id,title,abstract ,publication date)

# %%
#kidney
#breathing
#lung failure

# %% [markdown]
# ## Result Evaluation

# %%
# skipgram model

#Input your search query here

Query = "lung failure"

Results,sim = top_n(Query,skipgram_vectors,df1,skipgram)
Results

# %%
# fasttext model

#Input your search query here

Query = "breathe"

Results,sim=top_n(Query,fast_vectors,df1,FastText)
Results

# %% [markdown]
# # Streamlit App (Refer Medical.py file to run the app)

# %%
#streamlit function 
def main():
    # Load data and models
    data = df1     #our data which we have to display
    model = top_n  #top_n model to return n similar results
    

    st.title("Medical Search engine")      #title of our app
    st.write('Type your query here')       #text below title

    # User search
    user_input = st.text_input("Search box")   #getting input from user

   
    # Fetch results
    if user_input:
        
        P,sim =model(str(user_input),K2,data)     #storing our output dataframe in P
        #Plotly function to display our dataframe in form of plotly table
        fig = go.Figure(data=[go.Table(header=dict(values=['ID', 'Title','Abstract','Publication Date','Similarity']),cells=dict(values=[list(P['Trial ID'].values),list(P['Title'].values), list(P['Abstract'].values),list(P['Publication date'].values),list(np.around(sim,4))],align='center'))])
        #displying our plotly table
        fig.update_layout(height=1700) 
        st.plotly_chart(fig) 
        # Get individual results
    

if __name__ == "__main__":
    main()
# Out:
# 2021-07-21 19:57:17.728
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\91758\anaconda3\anaconda\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# !pip freeze > requirements.txt
# Out:
# WARNING: Could not generate requirement for distribution -cikit-learn 0.21.3 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-cikit-l'": Expected W:(abcd...)
